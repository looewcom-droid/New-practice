# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlite3

Data = pd.read_csv(r'C:\Users\looew\practice2\data-science-small-business\sheets\originals\Marketing.csv')
# Remove commas and convert
Data["Investimento (R$)"] = Data["Investimento (R$)"].str.replace(",", "")
Data["Investimento (R$)"] = pd.to_numeric(Data["Investimento (R$)"], errors="coerce")
Data["ROI (%)"] = pd.to_numeric(Data["ROI (%)"], errors="coerce")
Data["Return"] = Data["Investimento (R$)"] * (1 + Data["ROI (%)"]/100)

print(Data.head(10))
# Out:
#    ID Campanha   Canal Marketing  Investimento (R$)  ROI (%)  Custos (R$)  \
# 0            1       Publicidade              500.0      NaN        200.0
# 1            2          Cartazes              300.0     15.0        100.0
# 2            3             Rádio              800.0      8.0        400.0
# 3            4     Redes Sociais             1200.0     18.0        300.0
# 4            5  E-mail Marketing              350.0     25.0        100.0
# 5            6  Parcerias Locais              250.0     10.0        100.0
#
#    Alcance (Pessoas)  Return
# 0                 10     NaN
# 1                  5   345.0
# 2                 20   864.0
# 3                 30  1416.0
# 4                  4   437.5
# 5                  8   275.0
